# %% [markdown]
# <a href="https://colab.research.google.com/github/Averkios1/AV_3_6/blob/main/raspberry_to_colab_script2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Restart runtime before running this cell

# Install YOLOv5 + compatible dependencies only
# !pip install --upgrade --quiet pip
# !pip install --quiet torch torchvision torchaudio
# !pip install --quiet opencv-python==4.10.0.84 opencv-python-headless==4.10.0.84
# !pip install --quiet ultralytics==8.3.50
#!pip install --quiet git+https://github.com/ultralytics/yolov5.git
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.8 MB/s eta 0:00:00

# %%
# !git clone https://github.com/Averkios1/AV_3_6.git
# %cd /content/AV_3_6

# Check files
# !ls
# Out:
# Cloning into 'AV_3_6'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 91 (delta 7), reused 0 (delta 0), pack-reused 77 (from 1)
# Receiving objects: 100% (91/91), 144.58 MiB | 34.49 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# Updating files: 100% (51/51), done.
# /content/AV_3_6
#  app10.py		  detections_log.csv
#  app11.py		  LICENSE
#  app12.py		  mediamtxDIR
#  app14.py		  mediamtx_v1.12.3_linux_arm64.tar.gz
#  app15.py		  o
#  app16.py		  raspberry_to_colab_script2.ipynb
#  app17.py		  Weights_yolov5_15_9_25_v11_45epochs
#  app18.py		  Weights_yolov5_17_6_25
#  app19.py		  Weights_yolov5_20_9_25_v13_45epochs
#  app20.py		  Weights_yolov5_23_9_25_v13_45epochs
#  app21.py		  Weights_yolov5_23_9_25_v13_with_183images_45epochs
#  app23.py		  Weights_yolov5_23_9_25_v14_with_183images_45epochs
#  app24.py		  Weights_yolov5_24_9_25_v14_with_183images_45epochs
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !python app35_colab_2video.py --source1 "/content/AV_3_6/mast_video_reduced.mp4" \
--source2 "/content/AV_3_6/final_combined_video4.mp4" \
--weights "/content/AV_3_6/Weights_yolov5_24_9_25_v14_with_183images_45epochs/best.pt"
# Out:
# 🔹 Loading YOLOv5 model from: /content/AV_3_6/Weights_yolov5_24_9_25_v14_with_183images_45epochs/best.pt
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-11-4 Python-3.12.12 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# ✅ Model loaded successfully.
# 🚀 Starting inference in dual-video mode...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:898: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7A5225A87BF0>
# Processed frame 0 — Detections: 9
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:898: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %%
# !python app35_colab_1video.py --source1 "/content/AV_3_6/mast_video_reduced.mp4" \
--weights "/content/AV_3_6/Weights_yolov5_24_9_25_v14_with_183images_45epochs/best.pt"
# Out:
# 🔹 Loading YOLOv5 model from: /content/AV_3_6/Weights_yolov5_24_9_25_v14_with_183images_45epochs/best.pt
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-11-4 Python-3.12.12 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# ✅ Model loaded successfully.
# 🚀 Starting inference in single-video mode...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:898: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7BC9D67730B0>
# Processed frame 0 — Detections: 7
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:898: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %%
# !python app35_colab_1video.py #--source1 #"/content/AV_3_6/final_combined_video4.mp4" \
#--weights "/content/AV_3_6/Weights_yolov5_24_9_25_v14_with_183images_45epochs/best.pt"
# Out:
# 🔹 Loading YOLOv5 model from: /content/AV_3_6/Weights_yolov5_24_9_25_v14_with_183images_45epochs/best.pt
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-11-4 Python-3.12.12 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# ✅ Model loaded successfully.
# 🚀 Starting inference in single-video mode...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:898: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7967B2F434A0>
# Processed frame 0 — Detections: 7
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:898: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
